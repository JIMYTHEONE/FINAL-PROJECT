# %%
import pandas as pd
import numpy as np

# %%
# %pip install folium
# Out:
# ...
#      |████████████████████████████████| 96 kB 1.6 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
# crear mapa

mapa=folium.Map(location=[27.59, -86.43], # lat-lon del centro del mapa
                tiles='openstreetmap',    # estilo del mapa
                zoom_start=12             # zoom inicial
               )

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Map( 
   location=[40.965, -5.664], 
   tiles='Stamen Toner', 
   zoom_start=16 
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
peaks_loc = pd.read_csv('data/peaks_loc.csv')
unclimbed= pd.read_csv('data/unclimbed.csv')

# %%
peaks_loc.head()
# Out:
#   peak_id      peak_name host_contries  height_m  height_ft  \
# 0    AGLE     Agole East    Nepal only      6675      21900
# 1    AMAD     Ama Dablam    Nepal only      6814      22356
# 2    AMPH        Amphu I    Nepal only      6740      22113
# 3    ANID  Anidesh Chuli    Nepal only      6808      22336
# 4    ANN1    Annapurna I    Nepal only      8091      26545
#
#                   location                   region climb_status  is_open  \
# 0                Rolwaling  Khumbu-Rolwaling-Makalu    Unclimbed        1
# 1                   Khumbu  Khumbu-Rolwaling-Makalu      Climbed        1
# 2                   Khumbu  Khumbu-Rolwaling-Makalu      Climbed        1
# 3  Kangchenjunga/Simhalila      Kangchenjunga-Janak    Unclimbed        1
# 4                Annapurna   Annapurna-Damodar-Peri      Climbed        1
#
#    is_unlisted  is_trekking  trek_year  first_asc_yr first_asc_season  \
# 0            0            0          0             0              All
# ...

# %%
unclimbed.head()
# Out:
#   peak_id      peak_name  host_contries  height_m  height_ft  \
# 0    AGLE     Agole East     Nepal only      6675      21900
# 1    ANID  Anidesh Chuli     Nepal only      6808      22336
# 2    APIW       Api West     Nepal only      7076      23215
# 3    CHAB         Chabuk  Nepal & China      6792      22283
# 4    CHMR         Chamar     Nepal only      7161      23494
#
#                   location                   region climb_status  is_open  \
# 0                Rolwaling  Khumbu-Rolwaling-Makalu    Unclimbed        1
# 1  Kangchenjunga/Simhalila      Kangchenjunga-Janak    Unclimbed        1
# 2      Api/Byas Risi/Guras       Far West-Kanjiroba    Unclimbed        1
# 3        Janak/Ohmi Kangri      Kangchenjunga-Janak    Unclimbed        1
# 4           Ganesh/Shringi           Manaslu-Ganesh    Unclimbed        1
#
#    is_unlisted  is_trekking  trek_year  first_asc_yr first_asc_season  \
# 0            0            0          0             0              All
# ...

# %%
ochomiles = peaks_loc[peaks_loc['height_m'] >= 8000]
ochomiles.reset_index(inplace=True)

# %%
ochomiles[]

# %%
ochomiles['Lat'][4]
# Out:
# 28.3524

# %%
mapa2=folium.Map(location=[29.959167, 81.022500], 
                 tiles='Stamen Terrain', 
                 zoom_start=12)

lat=[i for i in peaks_loc['Lat']]
lng=[i for i in peaks_loc['Long']]

for i in range(len(peaks_loc)):
    folium.Marker([peaks_loc.Lat[i], peaks_loc.Long[i]],
                  popup=peaks_loc.peak_name[i] + ' ' +  str(peaks_loc.height_m[i]) + 'm', 
                  icon=folium.Icon(color='green', icon='flag', prefix='fa')).add_to(mapa2)

    
    
mapa2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
from folium import plugins


m = folium.Map(
    location=[35.68159659061569, 139.76451516151428],
    zoom_start=16
)



# longitud y latitud por orden.
lines = [
    {
        'coordinates': [
            [139.76451516151428, 35.68159659061569],
            [139.75964426994324, 35.682590062684206],
        ],
        'dates': [
            '2017-06-02T00:00:00',
            '2017-06-02T00:10:00'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [139.75964426994324, 35.682590062684206],
            [139.7575843334198, 35.679505030038506],
        ],
        'dates': [
            '2017-06-02T00:10:00',
            '2017-06-02T00:20:00'
        ],
        'color': 'blue'
    },
    {
        'coordinates': [
            [139.7575843334198, 35.679505030038506],
            [139.76337790489197, 35.678040905014065],
        ],
        'dates': [
            '2017-06-02T00:20:00',
            '2017-06-02T00:30:00'
        ],
        'color': 'green',
        'weight': 15,
    },
    {
        'coordinates': [
            [139.76337790489197, 35.678040905014065],
            [139.76451516151428, 35.68159659061569],
        ],
        'dates': [
            '2017-06-02T00:30:00',
            '2017-06-02T00:40:00'
        ],
        'color': '#FFFFFF',
    },
]




features = [
    {
        'type': 'Feature',
        'geometry': {
            'type': 'LineString',
            'coordinates': line['coordinates'],
        },
        'properties': {
            'times': line['dates'],
            'style': {
                'color': line['color'],
                'weight': line['weight'] if 'weight' in line else 5
            }
        }
    }
    for line in lines
]







plugins.TimestampedGeoJson({
    'type': 'FeatureCollection',
    'features': features,
}, period='PT1M', add_last_point=True).add_to(m)

#display(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
mapa2=folium.Map(location=[29.959167, 81.022500], 
                 tiles='Stamen Terrain', 
                 zoom_start=12)

lat=[i for i in peaks_loc['Lat']]
lng=[i for i in peaks_loc['Long']]

lat2=[i for i in unclimbed['Lat']]
lng2=[i for i in unclimbed['Long']]

for i in range(len(peaks_loc)):
    
    folium.Marker([peaks_loc.Lat[i], peaks_loc.Long[i]],
                  popup=peaks_loc.peak_name[i] + ' ' +  str(peaks_loc.height_m[i]) + 'm', 
                  icon=folium.Icon(color='green', icon='flag', prefix='fa')).add_to(mapa2)
    
for i in range(len(unclimbed)):
    
    folium.Marker([unclimbed.Lat[i], unclimbed.Long[i]],
                  popup= unclimbed.peak_name[i] + ' ' +  str(unclimbed.height_m[i]) + 'm', 
                  icon=folium.Icon(color='red', icon='eye-slash', prefix='fa')).add_to(mapa2)
    
for i in range(len(ochomiles)):
    
    folium.Marker([ochomiles.Lat[i], ochomiles.Long[i]],
                  popup= ochomiles.peak_name[i] + ' ' +  str(ochomiles.height_m[i]) + 'm', 
                  icon=folium.Icon(color='blue', icon='star', prefix='fa')).add_to(mapa2)
    
mapa2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
help(folium.Icon)
# Out:
# Help on class Icon in module folium.map:
#
# class Icon(branca.element.MacroElement)
#  |  Icon(color='blue', icon_color='white', icon='info-sign', angle=0, prefix='glyphicon', **kwargs)
#  |
#  |  Creates an Icon object that will be rendered
#  |  using Leaflet.awesome-markers.
#  |
#  |  Parameters
#  |  ----------
#  |  color : str, default 'blue'
#  |      The color of the marker. You can use:
#  |
#  |          ['red', 'blue', 'green', 'purple', 'orange', 'darkred',
#  |           'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue',
#  |           'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen',
#  |           'gray', 'black', 'lightgray']
#  |
#  |  icon_color : str, default 'white'
#  |      The color of the drawing on the marker. You can use colors above,
#  |      or an html color code.
#  |  icon : str, default 'info-sign'
#  |      The name of the marker sign.
#  |      See Font-Awesome website to choose yours.
# ...
