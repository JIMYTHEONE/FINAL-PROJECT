# %%
import pandas as pd
import numpy as np

# %%
# %pip install folium
# Out:
# ...
#      |████████████████████████████████| 96 kB 1.6 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
# crear mapa

mapa=folium.Map(location=[27.59, -86.43], # lat-lon del centro del mapa
                tiles='openstreetmap',    # estilo del mapa
                zoom_start=12             # zoom inicial
               )

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Map( 
   location=[40.965, -5.664], 
   tiles='Stamen Toner', 
   zoom_start=16 
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
peaks_loc = pd.read_csv('data/peaks_loc.csv')

# %%
peaks_loc.head()
# Out:
#   peak_id      peak_name host_contries  height_m  height_ft  \
# 0    AGLE     Agole East    Nepal only      6675      21900
# 1    AMAD     Ama Dablam    Nepal only      6814      22356
# 2    AMPH        Amphu I    Nepal only      6740      22113
# 3    ANID  Anidesh Chuli    Nepal only      6808      22336
# 4    ANN1    Annapurna I    Nepal only      8091      26545
#
#                   location                   region climb_status  is_open  \
# 0                Rolwaling  Khumbu-Rolwaling-Makalu    Unclimbed        1
# 1                   Khumbu  Khumbu-Rolwaling-Makalu      Climbed        1
# 2                   Khumbu  Khumbu-Rolwaling-Makalu      Climbed        1
# 3  Kangchenjunga/Simhalila      Kangchenjunga-Janak    Unclimbed        1
# 4                Annapurna   Annapurna-Damodar-Peri      Climbed        1
#
#    is_unlisted  is_trekking  trek_year  first_asc_yr first_asc_season  \
# 0            0            0          0             0              All
# ...

# %%
peaks_loc['Lat'][]
# Out:
#   Input In [50]
#     peaks_loc['Lat'][]
#                      ^
# SyntaxError: invalid syntax

# %%
m = folium.Map( 
    location=[peaks_loc['Lat'], peaks_loc['Long']], 
    zoom_start=12, 
    tiles='Stamen Terrain' 
) 
tooltip = peaks_loc['peak_name']
folium.Marker([29.959167, 81.022500], popup='Peak', tooltip=tooltip).add_to(m) 

m
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/folium/utilities.py:60, in validate_location(location)
#      59 try:
# ---> 60     float(coord)
#      61 except (TypeError, ValueError):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:191, in _coerce_method.<locals>.wrapper(self)
#     190     return converter(self.iloc[0])
# --> 191 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'float'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 m = folium.Map(
#       2     location=[peaks_loc['Lat'], peaks_loc['Long']],
#       3     zoom_start=12,
#       4     tiles='Stamen Terrain'
#       5 )
# ...
